# %%
#1.postional arguments
#sub ofv two numbers
def sub(x,y):
    return x-y
b1= int(input())
b2= int(input())
print(sub(b1,b2))
print(sub(b2,b1))
# Out:
#  5
#  10
# -5
# 5

# %%
#2keyword arguments
#sub of two numbers
def sub(x,y):
    return x-y
b1= int(input())
b2= int(input())
print(sub(x=b1,y=b2))
print(sub(y=b2,x=b1))
# Out:
#  24
#  23
# 1

# %%
def add(a,b,c):
    return a+b+c
b1= int(input())
b2= int(input())
b3= int(input())
print(add(b1,b2,b3))
print(add(b2,b3,b1))
# Out:
#  34
#  56
#  78
# 168

# %%
def add(a,b,c):
    return a+b+c
b1= int(input())
b2= int(input())
b3= int(input())
#print(add(a=b1,b=b2,c=b3))
print(add(b=b2,c=b3,a=b1))
# Out:
#  45
#  64
#  75
# 184
# 184

# %%
#3. deafult argument
def mul(a,b=0):
    return a*b
c1=int(input())
c2=int(input())
print(mul(b1,b2))
# Out:
#  450
#  34
# 2880

# %% [markdown]
# #### 3. deafult argument
# def mul(a,b,c,d):
#     return a*b*c*d
# B1=int(input())
# B2=int(input())
# B3=int(input())
# B4=int(input())
# #print(mul(B1,B2))
# #print(mul(B1,B2,B3))
# print(mul(B1,B2,B3,B4))

# %%
#.4.varibale length postoonal argument
#sum of four numbers
def add(x,y=0, *args):
    print(type(args))
    print(args)
    s=0
    for num in args:
        s+=num
        return s
print(add(10,20,30,40,50))
# Out:
# <class 'tuple'>
# (30, 40, 50)
# 30

# %%
#.5.varibale length keyword argument
def add(x,y=0,*args,**kwargs):
    print(x,y)
    print(type(args),args)
    print(type(kwargs),kwargs)
print(add(10,20,30,40,50,1,2,3,4,5,6, a=10,b=20,c=30))
print(add(10))
print(add (10,30))
# Out:
# 10 20
# <class 'tuple'> (30, 40, 50, 1, 2, 3, 4, 5, 6)
# <class 'dict'> {'a': 10, 'b': 20, 'c': 30}
# None
# 10 0
# <class 'tuple'> ()
# <class 'dict'> {}
# None
# 10 30
# <class 'tuple'> ()
# <class 'dict'> {}
# None

# %%
[1,2,3]+[4,5]
# Out:
# [1, 2, 3, 4, 5]
