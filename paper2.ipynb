# %%
num =(input())
year =int(input())
print(num.lower()+"@"+str(year))
# Out:
#  srinu
#  2025
# srinu@2025

# %%
name =(input())
year =int(input())
print(num.lower()+"@"+str(year))
# Out:
#  Srinu
#  abc
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 2
#       1 num =(input())
# ----> 2 year =int(input())
#       3 print(num.lower()+"@"+str(year))
#
# ValueError: invalid literal for int() with base 10: 'abc'
