# %%
l1=[]
l2=list()
l=10
print (l)
print(type(l1),type(l2))
# Out:
# 10
# <class 'list'> <class 'list'>

# %%
#### reading list of nubers from user
s=input().split()
print(type(s), s)
# Out:
#  34
# <class 'list'> ['34']

# %%
l=[1,2,3,4,5]
l.append(10)
print(l)
l.extend([10,20,30])
print(l)
#l.insert(100,1000)
#print(l)
l.insert(3,100)
print(l)
# Out:
# [1, 2, 3, 4, 5, 10]
# [1, 2, 3, 4, 5, 10, 10, 20, 30]
# [1, 2, 3, 100, 4, 5, 10, 10, 20, 30]

# %%
l=[10,20,30,40,50]
l.remove(30)
print(l)
val=l.pop()
print(val)
print(l)
l.clear()
print(l)
# Out:
# [10, 20, 40, 50]
# 50
# [10, 20, 40]
# []

# %%
l=[1,2,3,4,5,8,6,7]
val = l.index(4)
print(val)
#print(l.index(4,5))
#print(l.index(4,-1))
print(l.index(100))
# Out:
# 3
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 6
#       3 print(val)
#       4 #print(l.index(4,5))
#       5 #print(l.index(4,-1))
# ----> 6 print(l.index(100))
#
# ValueError: 100 is not in list

# %%
l=[1,2,3,4,5,2,5,2,3]
print(l.count(10))
print(l.count(2))
# Out:
# 0
# 3

# %%
l=[1,2,3,4,5,2,5,2,3]
print(min(l))
print(max(l))
print(sum(l))
print(len(l))
# Out:
# 1
# 5
# 27
# 9

# %%
l=['a','d','c','v','x','t','y','u']
print(min(l))
print(max(l))
#print(sum(l))
print(len(l))
# Out:
# a
# y
# 8

# %%
n=int(input())
present=0
absent=0
while loop:
    if val==0:
        absent+=1
        i +=1
        print("absent")
    elif val==1:
        present+=1
        print("present")
else:
    print("not valid")
       

    print("absent")
# Out:
#  1
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 4
#       2 present=0
#       3 absent=0
# ----> 4 while loop:
#       5     if val==0:
#       6         absent+=1
#
# NameError: name 'loop' is not defined
